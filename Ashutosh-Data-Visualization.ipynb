# %% [markdown]
# #### Importing Libraries

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# #### Read CSV

# %%
df = pd.read_csv('rideshare_kaggle.csv', index_col=0)

# %% [markdown]
# #### Displaying Head

# %%
df.head()
# Out:
#                                          timestamp  hour  day  month  \
# id
# 424553bb-7174-41ea-aeb4-fe06d4f4b9d7  1.544953e+09     9   16     12
# 4bd23055-6827-41c6-b23b-3c491f24e74d  1.543284e+09     2   27     11
# 981a3613-77af-4620-a42a-0c0866077d1e  1.543367e+09     1   28     11
# c2d88af2-d278-4bfd-a8d0-29ca77cc5512  1.543554e+09     4   30     11
# e0126e1f-8ca9-4f2e-82b3-50505a09db9a  1.543463e+09     3   29     11
#
#                                                  datetime          timezone  \
# id
# 424553bb-7174-41ea-aeb4-fe06d4f4b9d7  2018-12-16 09:30:07  America/New_York
# 4bd23055-6827-41c6-b23b-3c491f24e74d  2018-11-27 02:00:23  America/New_York
# 981a3613-77af-4620-a42a-0c0866077d1e  2018-11-28 01:00:22  America/New_York
# c2d88af2-d278-4bfd-a8d0-29ca77cc5512  2018-11-30 04:53:02  America/New_York
# e0126e1f-8ca9-4f2e-82b3-50505a09db9a  2018-11-29 03:49:20  America/New_York
#
#                                                 source    destination  \
# id
# ...

# %% [markdown]
# #### Data Cleaning . Clearing All NULL Values

# %%
df = df.dropna()
#df = df.sample(n=10000)

# %% [markdown]
# #### Scatter Plot of Price and Distance in accordance to Surge Multiplier (and remove the default regression line and tweak the graph limit with matplotlib)

# %%
sns.lmplot(x='distance', y='price', data=df,
           fit_reg=False,
           hue='surge_multiplier')
plt.xlim(0,8.5)
plt.ylim(0,110)
# Out:
# (0.0, 110.0)

# %% [markdown]
# #### Distance-Price Graph in Accordance to Surge Multiplier

# %%
#sns.set(rc={'figure.figsize':(11.7,20)})
colors = ['#009999','#00994C','#2e856e','#4C9900','#999900','#f46d75','#990000']

sns.relplot(x='distance', y='price', data=df, kind ='scatter',col_wrap=3,
            col='surge_multiplier',hue='surge_multiplier', palette=colors).set(title="Distance-Price graph in accordance to Surge Multiplier")

plt.xlim(0,8.5)
plt.ylim(0,110)
# Out:
# (0.0, 110.0)

# %% [markdown]
# #### 3D ploting the price-distance with surge_multiplier as z-axis and using a sample size of 10000

# %%
from mpl_toolkits.mplot3d import Axes3D
sns.set(style = "darkgrid")

new_df=df.sample(n=10000)
x = new_df['distance']
y = new_df['price']
z = new_df['surge_multiplier']

fig = plt.figure()
fig.set_size_inches(12, 12)
ax = plt.axes(projection ="3d")

ax.grid(b = True, color ='grey',
        linestyle ='-.', linewidth = 0.3,
        alpha = 0.2)

my_cmap = plt.get_cmap('hsv')

sctt = ax.scatter3D(x, y, z,
                    alpha = 0.8,
                    c=(x+y+z),
                    cmap = my_cmap,
                    marker ='^')

plt.title("Distance-Price graph in accordance to Surge Multiplier")
ax.set_xlabel("Distance",fontweight='bold')
ax.set_ylabel("Price",fontweight='bold')
ax.set_zlabel("Surge Multiplier",fontweight='bold')

ax.scatter(x, y, z)

plt.show()
# Out:
# C:\Users\avino\AppData\Local\Temp\ipykernel_2116\2975677032.py:13: MatplotlibDeprecationWarning: The 'b' parameter of grid() has been renamed 'visible' since Matplotlib 3.5; support for the old name will be dropped two minor releases later.
#   ax.grid(b = True, color ='grey',

# %% [markdown]
# #### Count of the number of cabs booked by LYFT and Uber

# %%
colors=['#FF00BF','#1fbad6']     #LYft and Uber colors
plt.title("Booked Cabs")
ax = sns.countplot(x='cab_type', data=df,palette=colors)
ax.bar_label(ax.containers[0])
ax.bar_label(ax.containers[0])
# Out:
# [Text(0, 0, '307408'), Text(0, 0, '330568')]

# %% [markdown]
# #### Cabs Boarded from a specific source location and which cab was chosen

# %%
plt.figure(figsize=(25,12))
colors=['#FF00BF','#1fbad6']
plt.title("Cabs boarded from source locations")
ax = sns.countplot(x='source',hue='cab_type', data=df,palette=colors)
ax.bar_label(ax.containers[0])
ax.bar_label(ax.containers[1])
# Out:
# [Text(0, 0, '32122'),
#  Text(0, 0, '32137'),
#  Text(0, 0, '32143'),
#  Text(0, 0, '31792'),
#  Text(0, 0, '31939'),
#  Text(0, 0, '32144'),
#  Text(0, 0, '32137'),
#  Text(0, 0, '32130'),
#  Text(0, 0, '32283'),
#  Text(0, 0, '32074'),
#  Text(0, 0, '32620'),
#  Text(0, 0, '32142')]

# %% [markdown]
# #### Cabs Boarded for a specific destination location and which cab was chosen

# %%
plt.figure(figsize=(25,12))
plt.title("Cabs boarded to destination locations")
ax = sns.countplot(x='destination',hue='cab_type', data=df,palette=colors)
ax.bar_label(ax.containers[0])
ax.bar_label(ax.containers[1])
# Out:
# [Text(0, 0, '27251'),
#  Text(0, 0, '27546'),
#  Text(0, 0, '27498'),
#  Text(0, 0, '27558'),
#  Text(0, 0, '27539'),
#  Text(0, 0, '27546'),
#  Text(0, 0, '27653'),
#  Text(0, 0, '27376'),
#  Text(0, 0, '27540'),
#  Text(0, 0, '27550'),
#  Text(0, 0, '27954'),
#  Text(0, 0, '27557')]

# %% [markdown]
# #### Shows the type of cab people prefer to use

# %%
plt.figure(figsize=(25,12))
plt.title("The type of Cab chosen")
ax = sns.countplot(x='name',hue='cab_type', data=df,palette=colors)
ax.bar_label(ax.containers[0])
ax.bar_label(ax.containers[1])
# Out:
# [Text(0, 0, '0'),
#  Text(0, 0, '0'),
#  Text(0, 0, '0'),
#  Text(0, 0, '0'),
#  Text(0, 0, '0'),
#  Text(0, 0, '0'),
#  Text(0, 0, '55096'),
#  Text(0, 0, '55095'),
#  Text(0, 0, '55094'),
#  Text(0, 0, '55096'),
#  Text(0, 0, '55096'),
#  Text(0, 0, '55091'),
#  Text(0, 0, '55095')]
